# %%
import xlrd
import pymysql
import math
import pandas as pd
from sqlalchemy import create_engine

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()
cur.execute("SET NAMES utf8")

sql_cmd = "SELECT  * FROM music.Excel7;"
df = pd.read_sql(sql_cmd,conn)
df
# Out:
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#             id                                 link class  singer_id  \
# 0       100000   http://mojim.com/twy100198x2x2.htm  男生歌手     100198
# 1       100042  http://mojim.com/twy100198x10x4.htm  男生歌手     100198
# 2       131843  http://mojim.com/twy100146x17x6.htm  女生歌手     100146
# 3        84942  http://mojim.com/twy100431x1x10.htm  男生歌手     100431
# 4       125851   http://mojim.com/twy100362x1x7.htm  女生歌手     100362
# ...        ...                                  ...   ...        ...
# 261817  293084   http://mojim.com/twy105001x1x1.htm  其他歌手     105001
# 261818  293085   http://mojim.com/twy105001x2x1.htm  其他歌手     105001
# 261819  293086   http://mojim.com/twy105001x3x1.htm  其他歌手     105001
# 261820  293087   http://mojim.com/twy105001x4x1.htm  其他歌手     105001
# 261821  293088   http://mojim.com/twy105001x6x1.htm  其他歌手     105001
#
#         group_id singer_name      song_id  song_name  song_word   album_id  \
# 0            0.0         張洪量   1001980202       情為何物          4   10019802
# 1            0.0         張洪量  10019801004       情為何物          4  100198010
# 2            0.0         葉璦菱  10014601706       情為何物          4  100146017
# 3            0.0          費翔  10043101010       情為何物          4   10043101
# 4            0.0         楊采妮   1003620107       情為何物          4   10036201
# ...          ...         ...          ...        ...        ...        ...
# 261817       0.0      網友音樂創作   1050010101  痛徹心扉(孫培恩)          4   10500101
# 261818       0.0      網友音樂創作   1050010201         朝代          2   10500102
# 261819       0.0      網友音樂創作   1050010301      愛情的樂章          5   10500103
# 261820       0.0      網友音樂創作   1050010401     妳離開的事實          6   10500104
# 261821       0.0      網友音樂創作   1050010601    分開的最後一天          7   10500106
#
#         album_name album_language  lyric_id same_id lyric_language years  \
# 0             整個給你             國語    100000  100000        Chinese  1993
# 1               祭文             國語    100042  100000        Chinese  1987
# 2            百萬金曲1             國語    131843   84942        Chinese  1905
# 3       想念依舊[費翔精選]             國語     84942   84942        Chinese  2000
# 4             為所欲為             國語    125851  125851        Chinese  1996
# ...            ...            ...       ...     ...            ...   ...
# 261817        痛徹心扉             國語    293084  293084        Chinese    未知
# 261818          朝代             國語    293085  293085        Chinese    未知
# 261819       愛情的樂章             國語    293086  293086        Chinese    未知
# 261820      你離開的事實             國語    293087  293087        Chinese    未知
# 261821          暫存             國語    293088  293088        Chinese    未知
#
#        month author_name                       composer_name
# 0          1         張洪量                                 張洪量
# 1          9         張洪量                                 張洪量
# 2          6          小軒                                 譚健常
# 3          3          小軒                                 譚健常
# 4          1          未知                                  未知
# ...      ...         ...                                 ...
# 261817    未知          未知                                  未知
# 261818    未知         口香糖                                  未知
# 261819    未知          未知                                  未知
# 261820    未知          小凱  PianoBoy(The truth that you leave)
# 261821    未知          未知                                  未知
#
# [261822 rows x 19 columns]

# %%
df1=df[['album_id','album_name']]
# df1= df1.drop_duplicates()
# df1[df1.duplicated()].count()
df1.sort_values('album_id')
# Out:
#           album_id                      album_name
# 233044    10000101                      [第一張專輯]新台幣
# 46730     10000101                      [第一張專輯]新台幣
# 172541    10000101                      [第一張專輯]新台幣
# 233046    10000101                      [第一張專輯]新台幣
# 233043    10000101                      [第一張專輯]新台幣
# ...            ...                             ...
# 102200  1809330127  港故仔 更多故事 雙碟版 (MORE HK Stories)
# 102201  1809330127  港故仔 更多故事 雙碟版 (MORE HK Stories)
# 102193  1809330127  港故仔 更多故事 雙碟版 (MORE HK Stories)
# 102323  1809330129                            香港80
# 102324  1809330130                        全聯福利熊主題曲
#
# [261822 rows x 2 columns]

# %%
data_dict=df1.to_dict('records')
print(len(data_dict))
print(data_dict[0])
indices=dict()

for doc in data_dict[:]:
#     print(doc)
   
        if doc['album_id'] not in indices:
            indices[doc['album_id']]=[]
        indices[doc['album_id']].append(str(doc['album_name']))
# indices

list_key_values=[[k,v] for k ,v in indices.items()]

df_if=pd.DataFrame.from_dict(list_key_values)
df_if.columns=['album_id','album_name']

list_key_values=[[k,v] for k ,v in indices.items()]

df_if=pd.DataFrame.from_dict(list_key_values)
df_if.columns=['album_id','album_name']
df_if

df_if['album_song']=[len(l) for l in df_if.album_name.values]
df_if.sort_values('album_song')
# Out:
# 261822
# {'album_id': 10019802, 'album_name': '整個給你'}
#          album_id                                         album_name  \
# 36118    10500106                                               [暫存]
# 27277    12055506                                              [萌二代]
# 27276    12055507                                           [别讓我放不下]
# 27275    12055508                                            [吃貨進行曲]
# 27274   120555010                                           [聽你愛聽的歌]
# ...           ...                                                ...
# 13220   106299038  [青梅竹馬101, 青梅竹馬101, 青梅竹馬101, 青梅竹馬101, 青梅竹馬101, ...
# 73      100170087  [True Legend, True Legend, True Legend, True L...
# 31344    17246604  [Sing to Jehovah, Sing to Jehovah, Sing to Jeh...
# 871    1005150113  [歌林 黃金10年 (上集), 歌林 黃金10年 (上集), 歌林 黃金10年 (上集), ...
# 62       10238102  [金韻獎, 金韻獎, 金韻獎, 金韻獎, 金韻獎, 金韻獎, 金韻獎, 金韻獎, 金韻獎, ...
#
#        album_song
# 36118           1
# 27277           1
# 27276           1
# 27275           1
# 27274           1
# ...           ...
# 13220         101
# 73            101
# 31344         112
# 871           144
# 62            190
#
# [36119 rows x 3 columns]

# %%
df2=df_if[['album_id','album_song']]
df2
# Out:
#         album_id  album_song
# 0       10019802          10
# 1      100198010           9
# 2      100146017          10
# 3       10043101          20
# 4       10036201          10
# ...          ...         ...
# 36114   10500101           1
# 36115   10500102           1
# 36116   10500103           1
# 36117   10500104           1
# 36118   10500106           1
#
# [36119 rows x 2 columns]

# %%
df3=pd.merge(df,df2,on='album_id',how='inner')
df3
# Out:
#             id                                link class  singer_id  group_id  \
# 0       100000  http://mojim.com/twy100198x2x2.htm  男生歌手     100198       0.0
# 1       100002  http://mojim.com/twy100198x2x4.htm  男生歌手     100198       0.0
# 2       100005  http://mojim.com/twy100198x2x7.htm  男生歌手     100198       0.0
# 3       100006  http://mojim.com/twy100198x2x8.htm  男生歌手     100198       0.0
# 4       100007  http://mojim.com/twy100198x2x9.htm  男生歌手     100198       0.0
# ...        ...                                 ...   ...        ...       ...
# 261817  293084  http://mojim.com/twy105001x1x1.htm  其他歌手     105001       0.0
# 261818  293085  http://mojim.com/twy105001x2x1.htm  其他歌手     105001       0.0
# 261819  293086  http://mojim.com/twy105001x3x1.htm  其他歌手     105001       0.0
# 261820  293087  http://mojim.com/twy105001x4x1.htm  其他歌手     105001       0.0
# 261821  293088  http://mojim.com/twy105001x6x1.htm  其他歌手     105001       0.0
#
#        singer_name     song_id  song_name  song_word  album_id album_name  \
# 0              張洪量  1001980202       情為何物          4  10019802       整個給你
# 1              張洪量  1001980204         浮萍          2  10019802       整個給你
# 2              張洪量  1001980207       沙漠之花          4  10019802       整個給你
# 3              張洪量  1001980208      我想我瘋了          5  10019802       整個給你
# 4              張洪量  1001980209        外星戀          3  10019802       整個給你
# ...            ...         ...        ...        ...       ...        ...
# 261817      網友音樂創作  1050010101  痛徹心扉(孫培恩)          4  10500101       痛徹心扉
# 261818      網友音樂創作  1050010201         朝代          2  10500102         朝代
# 261819      網友音樂創作  1050010301      愛情的樂章          5  10500103      愛情的樂章
# 261820      網友音樂創作  1050010401     妳離開的事實          6  10500104     你離開的事實
# 261821      網友音樂創作  1050010601    分開的最後一天          7  10500106         暫存
#
#        album_language  lyric_id same_id lyric_language years month  \
# 0                  國語    100000  100000        Chinese  1993     1
# 1                  國語    100002  100002        Chinese  1993     1
# 2                  國語    100005  100005        Chinese  1993     1
# 3                  國語    100006  100006        Chinese  1993     1
# 4                  國語    100007  100007        Chinese  1993     1
# ...               ...       ...     ...            ...   ...   ...
# 261817             國語    293084  293084        Chinese    未知    未知
# 261818             國語    293085  293085        Chinese    未知    未知
# 261819             國語    293086  293086        Chinese    未知    未知
# 261820             國語    293087  293087        Chinese    未知    未知
# 261821             國語    293088  293088        Chinese    未知    未知
#
#        author_name                       composer_name  album_song
# 0              張洪量                                 張洪量          10
# 1              張洪量                                 張洪量          10
# 2              張洪量                                 張洪量          10
# 3              張洪量                                 張洪量          10
# 4              張洪量                                 張洪量          10
# ...            ...                                 ...         ...
# 261817          未知                                  未知           1
# 261818         口香糖                                  未知           1
# 261819          未知                                  未知           1
# 261820          小凱  PianoBoy(The truth that you leave)           1
# 261821          未知                                  未知           1
#
# [261822 rows x 20 columns]

# %%
cur.close()
conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8')  

pd.io.sql.to_sql(df3, "Excel7", conn,index=False, if_exists='replace')
