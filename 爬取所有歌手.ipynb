# %%
import xlrd
import pymysql
import math
import pandas as pd
from sqlalchemy import create_engine
from bs4 import BeautifulSoup 
import requests 
import re 
import random

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()

# %%
list1=[]
for i in range(2000,2021):
    if i==2020:
         for j in range(1,5):
            mm='{:0>2d}'.format(j)
            list1.append(str(i)+'-'+mm+'.htm')
    else:
        for j in range(1,13):
            mm='{:0>2d}'.format(j)
            list1.append(str(i)+'-'+mm+'.htm')
print(list1)
# Out:
# ['2000-01.htm', '2000-02.htm', '2000-03.htm', '2000-04.htm', '2000-05.htm', '2000-06.htm', '2000-07.htm', '2000-08.htm', '2000-09.htm', '2000-10.htm', '2000-11.htm', '2000-12.htm', '2001-01.htm', '2001-02.htm', '2001-03.htm', '2001-04.htm', '2001-05.htm', '2001-06.htm', '2001-07.htm', '2001-08.htm', '2001-09.htm', '2001-10.htm', '2001-11.htm', '2001-12.htm', '2002-01.htm', '2002-02.htm', '2002-03.htm', '2002-04.htm', '2002-05.htm', '2002-06.htm', '2002-07.htm', '2002-08.htm', '2002-09.htm', '2002-10.htm', '2002-11.htm', '2002-12.htm', '2003-01.htm', '2003-02.htm', '2003-03.htm', '2003-04.htm', '2003-05.htm', '2003-06.htm', '2003-07.htm', '2003-08.htm', '2003-09.htm', '2003-10.htm', '2003-11.htm', '2003-12.htm', '2004-01.htm', '2004-02.htm', '2004-03.htm', '2004-04.htm', '2004-05.htm', '2004-06.htm', '2004-07.htm', '2004-08.htm', '2004-09.htm', '2004-10.htm', '2004-11.htm', '2004-12.htm', '2005-01.htm', '2005-02.htm', '2005-03.htm', '2005-04.htm', '2005-05.htm', '2005-06.htm', '2005-0
# ...

# %%
list1[225:226]
# Out:
# ['2018-10.htm']

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()



for i in list1[:226]:
    album_list=[]
    url='http://mojim.com/twzlist'+i
#     print(url)
    resp = requests.get(url) #  
    soup = BeautifulSoup(resp.text, 'html.parser')
    ss=soup.find_all('a',class_='X2')
    
    
    for j in ss:
        
        if 'x'  in j['href']:
            year=i.split('.htm')[0]
            data=j['title'].split('歌詞')
            link=j['href']
            singer=data[0]
            album=data[1]
            v=[year,singer,album,link]
            album_list.append(v)
            sql = "INSERT IGNORE INTO year_singer_album (year,singer,album,link) VALUES (%s,%s,%s,%s)" 
            
    cur.executemany(sql, tuple(album_list))  
    conn.commit()
#             print(i['href'],i['title'])

# singer_list=list(set(album_list))
# print(album_list)
# print(len(album_list))
# df1=pd.DataFrame(album_list)
# df1.columns=['year','singer','album','link']
# # df1
# conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8')  

# pd.io.sql.to_sql(df1, "year_singer_album", conn,index=False, if_exists='replace')
print('finish')
# Out:
# finish

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()

album_list=[]
for i in list1[:]:
    url='http://mojim.com/twzlist'+i
#     print(url)
    resp = requests.get(url) #  
    soup = BeautifulSoup(resp.text, 'html.parser')
    ss=soup.find_all('a',class_='X2')
    
    
    for j in ss:
        
        if 'x'  in j['href']:
            d=i.split('.htm')[0]
            y=d.split('-')[0]
            m=d.split('-')[1]
            a=j['title'].split('歌詞')[1]
            l=j['href']
            values=(a,l,d,y,m)
            album_list.append(values)
            
    sql = "INSERT IGNORE INTO new_all_album (album_name,album_link,day,years,months) VALUES (%s,%s, %s, %s, %s)"                      
    cur.executemany(sql, tuple(album_list))    
    conn.commit()
    
# df1=pd.DataFrame(singer_list)
# df1.tail(5)
# Out:
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1300, "Invalid utf8 character string: 'F0A0B1'")
#   result = self._query(query)
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\xA0\\xB1\\x81\\xE6\\x88...' for column 'album_name' at row 14545")
#   result = self._query(query)
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1300, "Invalid utf8 character string: 'F09F90'")
#   result = self._query(query)
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x90\\xBC' for column 'album_name' at row 13836")
#   result = self._query(query)

# %%
df1.columns=['year','album_name','album_link']
df1
# Out:
#                year      album_name        album_link
# 0       2000-01.htm       Only Love   /tw101108x3.htm
# 1       2000-01.htm   The Best Hits   /tw100711x7.htm
# 2       2000-01.htm            感心感謝   /tw100369x1.htm
# 3       2000-01.htm            この愛に   /tw114487x4.htm
# 4       2000-01.htm      歌芝居 涙の歌謡劇場   /tw113490x1.htm
# ...             ...             ...               ...
# 110087  2020-04.htm              無心   /tw221835x3.htm
# 110088  2020-04.htm          jalopy   /tw221698x2.htm
# 110089  2020-04.htm        春暖花開奔你而來  /tw221693x10.htm
# 110090  2020-04.htm          三日月オペラ   /tw220806x2.htm
# 110091  2020-04.htm        舞い落ちる花びら  /tw174844x15.htm
#
# [110092 rows x 3 columns]

# %%
df1['day']=[i.split('.htm')[0]for i in df1.year]
df1['years']=[i.split('-')[0] for i in df1.day]
df1['months']=[i.split('-')[1] for i in df1.day]
df1
# Out:
#                year      album_name        album_link      day years months
# 0       2000-01.htm       Only Love   /tw101108x3.htm  2000-01  2000     01
# 1       2000-01.htm   The Best Hits   /tw100711x7.htm  2000-01  2000     01
# 2       2000-01.htm            感心感謝   /tw100369x1.htm  2000-01  2000     01
# 3       2000-01.htm            この愛に   /tw114487x4.htm  2000-01  2000     01
# 4       2000-01.htm      歌芝居 涙の歌謡劇場   /tw113490x1.htm  2000-01  2000     01
# ...             ...             ...               ...      ...   ...    ...
# 110087  2020-04.htm              無心   /tw221835x3.htm  2020-04  2020     04
# 110088  2020-04.htm          jalopy   /tw221698x2.htm  2020-04  2020     04
# 110089  2020-04.htm        春暖花開奔你而來  /tw221693x10.htm  2020-04  2020     04
# 110090  2020-04.htm          三日月オペラ   /tw220806x2.htm  2020-04  2020     04
# 110091  2020-04.htm        舞い落ちる花びら  /tw174844x15.htm  2020-04  2020     04
#
# [110092 rows x 6 columns]

# %%
df1=df1.drop(['year'],1)
df1
# Out:
#             album_name        album_link      day years months
# 0            Only Love   /tw101108x3.htm  2000-01  2000     01
# 1        The Best Hits   /tw100711x7.htm  2000-01  2000     01
# 2                 感心感謝   /tw100369x1.htm  2000-01  2000     01
# 3                 この愛に   /tw114487x4.htm  2000-01  2000     01
# 4           歌芝居 涙の歌謡劇場   /tw113490x1.htm  2000-01  2000     01
# ...                ...               ...      ...   ...    ...
# 110087              無心   /tw221835x3.htm  2020-04  2020     04
# 110088          jalopy   /tw221698x2.htm  2020-04  2020     04
# 110089        春暖花開奔你而來  /tw221693x10.htm  2020-04  2020     04
# 110090          三日月オペラ   /tw220806x2.htm  2020-04  2020     04
# 110091        舞い落ちる花びら  /tw174844x15.htm  2020-04  2020     04
#
# [110092 rows x 5 columns]

# %%
df1['months']=df1['months'].apply(str)

# %%
df1['album_link']=df1['album_link'].apply(str)
df1['album_name']=df1['album_name'].apply(str)
df1['day']=df1['day'].apply(str)
df1['years']=df1['years'].apply(str)
df1
# Out:
#             album_name        album_link      day years months
# 0            Only Love   /tw101108x3.htm  2000-01  2000     01
# 1        The Best Hits   /tw100711x7.htm  2000-01  2000     01
# 2                 感心感謝   /tw100369x1.htm  2000-01  2000     01
# 3                 この愛に   /tw114487x4.htm  2000-01  2000     01
# 4           歌芝居 涙の歌謡劇場   /tw113490x1.htm  2000-01  2000     01
# ...                ...               ...      ...   ...    ...
# 110087              無心   /tw221835x3.htm  2020-04  2020     04
# 110088          jalopy   /tw221698x2.htm  2020-04  2020     04
# 110089        春暖花開奔你而來  /tw221693x10.htm  2020-04  2020     04
# 110090          三日月オペラ   /tw220806x2.htm  2020-04  2020     04
# 110091        舞い落ちる花びら  /tw174844x15.htm  2020-04  2020     04
#
# [110092 rows x 5 columns]

# %%
df1['album_name']=[re.sub(r"^\s+|\s+$", "", i) for i in df1.album_name]
df1['album_link']=[re.sub(r"^\s+|\s+$", "", i) for i in df1.album_link]
df1['day']=[re.sub(r"^\s+|\s+$", "", i) for i in df1.day]
df1['years']=[re.sub(r"^\s+|\s+$", "", i) for i in df1.years]
df1['months']=[re.sub(r"^\s+|\s+$", "", i) for i in df1.months]
df1
# Out:
#            album_name        album_link      day years months
# 0           Only Love   /tw101108x3.htm  2000-01  2000     01
# 1       The Best Hits   /tw100711x7.htm  2000-01  2000     01
# 2                感心感謝   /tw100369x1.htm  2000-01  2000     01
# 3                この愛に   /tw114487x4.htm  2000-01  2000     01
# 4          歌芝居 涙の歌謡劇場   /tw113490x1.htm  2000-01  2000     01
# ...               ...               ...      ...   ...    ...
# 110087             無心   /tw221835x3.htm  2020-04  2020     04
# 110088         jalopy   /tw221698x2.htm  2020-04  2020     04
# 110089       春暖花開奔你而來  /tw221693x10.htm  2020-04  2020     04
# 110090         三日月オペラ   /tw220806x2.htm  2020-04  2020     04
# 110091       舞い落ちる花びら  /tw174844x15.htm  2020-04  2020     04
#
# [110092 rows x 5 columns]

# %%
df1[df1['album_name']=='Only Love']
# Out:
#       album_name        album_link      day years months
# 0      Only Love   /tw101108x3.htm  2000-01  2000     01
# 27701  Only Love   /tw105721x2.htm  2008-12  2008     12
# 30626  Only Love  /tw100166x15.htm  2009-06  2009     06

# %%
df1[14531:]
# Out:
#              album_name        album_link      day years months
# 14531   SWEET SUSPICION  /tw104858x51.htm  2005-07  2005     07
# 14532              依韻瓊瑤   /tw104541x1.htm  2005-07  2005     07
# 14533              幸福下載   /tw104334x2.htm  2005-07  2005     07
# 14534      二十年白金暢銷金曲全記錄  /tw100183x97.htm  2005-07  2005     07
# 14535         霹靂英雄劇集原聲帶   /tw102188x6.htm  2005-07  2005     07
# ...                 ...               ...      ...   ...    ...
# 110087               無心   /tw221835x3.htm  2020-04  2020     04
# 110088           jalopy   /tw221698x2.htm  2020-04  2020     04
# 110089         春暖花開奔你而來  /tw221693x10.htm  2020-04  2020     04
# 110090           三日月オペラ   /tw220806x2.htm  2020-04  2020     04
# 110091         舞い落ちる花びら  /tw174844x15.htm  2020-04  2020     04
#
# [95561 rows x 5 columns]

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()


conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8')  

pd.io.sql.to_sql(df1, "new_album", conn,index=False, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# /usr/local/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# ...

# %%
df1.columns=['singer_url']
df1
singer_list=[]
for i in df1[:].singer_url:
    url='https://mojim.com'+i
#     print('url',url)
    resp = requests.get(url) #  
    soup = BeautifulSoup(resp.text, 'html.parser')
    ss=soup.find_all('a',class_='X3')
    list1=[]
    for j in ss:
        if '\n魔鏡歌詞網\n' not in j.text:
            list1.append(j.text)
#     print(list1)
    singer_list.append(list1)
# print('singer_list',singer_list)
df2=pd.DataFrame(singer_list)
df2.columns=['class','name']
df2
conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8')  

pd.io.sql.to_sql(df2, "new_singer_class", conn,index=False, if_exists='replace')
