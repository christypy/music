# %%
import xlrd
import pymysql
import math
import pandas as pd
from sqlalchemy import create_engine

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()
cur.execute("SET NAMES utf8")

sql_cmd = "SELECT * FROM music.Excel9;"
df = pd.read_sql(sql_cmd,conn)
df
# Out:
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#             id                                link class singer_id  \
# 0       100000  http://mojim.com/twy100198x2x2.htm  男生歌手         1
# 1       100002  http://mojim.com/twy100198x2x4.htm  男生歌手         1
# 2       100005  http://mojim.com/twy100198x2x7.htm  男生歌手         1
# 3       100006  http://mojim.com/twy100198x2x8.htm  男生歌手         1
# 4       100007  http://mojim.com/twy100198x2x9.htm  男生歌手         1
# ...        ...                                 ...   ...       ...
# 261484  293084  http://mojim.com/twy105001x1x1.htm  其他歌手      9025
# 261485  293085  http://mojim.com/twy105001x2x1.htm  其他歌手      9025
# 261486  293086  http://mojim.com/twy105001x3x1.htm  其他歌手      9025
# ...

# %%
df['link']=['https'+i.split('http')[1]  for i in df.link.values]

# %%
df
# Out:
#             id                                 link class singer_id  \
# 0       100000  https://mojim.com/twy100198x2x2.htm  男生歌手         1
# 1       100002  https://mojim.com/twy100198x2x4.htm  男生歌手         1
# 2       100005  https://mojim.com/twy100198x2x7.htm  男生歌手         1
# 3       100006  https://mojim.com/twy100198x2x8.htm  男生歌手         1
# 4       100007  https://mojim.com/twy100198x2x9.htm  男生歌手         1
# ...        ...                                  ...   ...       ...
# 261484  293084  https://mojim.com/twy105001x1x1.htm  其他歌手      9025
# 261485  293085  https://mojim.com/twy105001x2x1.htm  其他歌手      9025
# 261486  293086  https://mojim.com/twy105001x3x1.htm  其他歌手      9025
# 261487  293087  https://mojim.com/twy105001x4x1.htm  其他歌手      9025
# 261488  293088  https://mojim.com/twy105001x6x1.htm  其他歌手      9025
#
#        singer_name  same_singer_id  group_id     song_id  song_name  \
# 0              張洪量          100198       0.0  1001980202       情為何物
# ...

# %%
cur.close() 
conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8')  

pd.io.sql.to_sql(df, "Excel10", conn,index=False, if_exists='replace')
