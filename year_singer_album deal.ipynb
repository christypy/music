# %%
import xlrd
import pymysql
import math
import pandas as pd
from sqlalchemy import create_engine
from bs4 import BeautifulSoup 
import requests 
import re 
import random

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()
cur.execute("SET NAMES utf8")

sql_cmd = "SELECT * FROM music.year_singer_album;"
df = pd.read_sql(sql_cmd,conn)
df.head(5)
# Out:
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#       year        singer             album              link
# 0  2018-11          江美琪                 家珍  /tw100030x24.htm
# 1  2018-11          施文彬               無輸無贏  /tw100246x26.htm
# 2  2018-11      Tomo GÖ           BUSINESS   /tw204490x2.htm
# 3  2018-11        ちゃんみな     PAIN IS BEAUTY   /tw182558x5.htm
# 4  2018-11  Alan Walker    Different World   /tw169709x9.htm

# %%
df['years']=[l.split('-')[0] for l in df.year]
df['months']=[l.split('-')[1] for l in df.year]
df['album_id']=[l.replace('.htm','').replace('/tw','').replace('x','0') for l in df.link]
df
# Out:
#            year        singer             album              link years  \
# 0       2018-11          江美琪                 家珍  /tw100030x24.htm  2018
# 1       2018-11          施文彬               無輸無贏  /tw100246x26.htm  2018
# 2       2018-11      Tomo GÖ           BUSINESS   /tw204490x2.htm  2018
# 3       2018-11        ちゃんみな     PAIN IS BEAUTY   /tw182558x5.htm  2018
# 4       2018-11  Alan Walker    Different World   /tw169709x9.htm  2018
# ...         ...           ...               ...               ...   ...
# 110212  2018-10         175R        ANNIVERSARY  /tw107872x20.htm  2018
# 110213  2018-10   Kis-My-Ft2               君、僕。  /tw107208x32.htm  2018
# 110214  2018-10  Mr.Children              重力と呼吸  /tw100750x40.htm  2018
# 110215  2018-10          崔澤飛           你的話傷了我的心   /tw223165x1.htm  2018
# 110216  2018-10         シガーラ          ブライター・デイズ   /tw221192x1.htm  2018
#
#        months   album_id
# 0          11  100030024
# 1          11  100246026
# ...

# %%
type(df['years'][0])
type(df['months'][0])
# Out:
# str

# %%
# df['years']=df['years'].astype(int)
# df['months']=df['months'].astype(int)
df['album_id']=df['album_id'].astype(int)

# %%
sql_cmd = "SELECT * FROM music.Excel17;" 
df1 = pd.read_sql(sql_cmd,conn) 
df1.head(5)
# Out:
#        id                                 link class  singer_id singer_name  \
# 0  100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198         張洪量
# 1  100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198         張洪量
# 2  100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198         張洪量
# 3  100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198         張洪量
# 4  100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198         張洪量
#
#       song_id song_name  song_word  album_id album_name  ... years  months  \
# 0  1001980202     情為何物           4  10019802      整個給你   ...  1993      01
# 1  1001980204       浮萍           2  10019802      整個給你   ...  1993      01
# 2  1001980207     沙漠之花           4  10019802      整個給你   ...  1993      01
# 3  1001980208    我想我瘋了           5  10019802      整個給你   ...  1993      01
# 4  1001980209      外星戀           3  10019802      整個給你   ...  1993      01
#
# ...

# %%
# df1['years']=df1['years'].astype(int) 
# df1['months']=df1['months'].astype(int)  
# df1['album_id']=df1['album_id'].astype(int)

# %%
df2=df[['album_id','years','months']]
df3=df1
df4=pd.merge(df3,df2,on='album_id',how='left')
df4
# Out:
#             id                                 link class  singer_id  \
# 0       100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198
# 1       100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198
# 2       100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198
# 3       100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198
# 4       100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198
# ...        ...                                  ...   ...        ...
# 261484  293084  https://mojim.com/twy105001x1x1.htm  其他歌手     105001
# 261485  293085  https://mojim.com/twy105001x2x1.htm  其他歌手     105001
# 261486  293086  https://mojim.com/twy105001x3x1.htm  其他歌手     105001
# 261487  293087  https://mojim.com/twy105001x4x1.htm  其他歌手     105001
# 261488  293088  https://mojim.com/twy105001x6x1.htm  其他歌手     105001
#
#        singer_name     song_id   song_name  song_word  album_id album_name  \
# ...

# %%
df4=df4.fillna('無對應')
df4
# Out:
#             id                                 link class  singer_id  \
# 0       100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198
# 1       100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198
# 2       100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198
# 3       100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198
# 4       100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198
# ...        ...                                  ...   ...        ...
# 261484  293084  https://mojim.com/twy105001x1x1.htm  其他歌手     105001
# 261485  293085  https://mojim.com/twy105001x2x1.htm  其他歌手     105001
# 261486  293086  https://mojim.com/twy105001x3x1.htm  其他歌手     105001
# 261487  293087  https://mojim.com/twy105001x4x1.htm  其他歌手     105001
# 261488  293088  https://mojim.com/twy105001x6x1.htm  其他歌手     105001
#
#        singer_name     song_id   song_name  song_word  album_id album_name  \
# ...

# %%
df4=df4.drop_duplicates()

# %%
df4.loc[(df4.years_y!='無對應')&(df4.years_x!=df4.years_y),'years_x']=df4.years_y
df4.loc[(df4.years_y!='無對應')&(df4.years_x!=df4.years_y),'months_x']=df4.months_y

# %%
df4[df4['years_x']>'2000'].years_x.unique()
# Out:
# array(['2004', '2003', '未記錄', '2016', '2001', '2013', '2007', '2014',
#        '2002', '2005', '2009', '2008', '2010', '2006', '2012', '2011',
#        '2017', '2019', '2015', '2018', '2020'], dtype=object)

# %%
df4.loc[(df4.years_x>'2000')&(df4.years_x!=df4.years_y)&(df4.years_x=='未記錄')&(df4.years_y!='無對應')]
# Out:
# Empty DataFrame
# Columns: [id, link, class, singer_id, singer_name, song_id, song_name, song_word, album_id, album_name, album_language, album_song, years_x, months_x, lyric_id, same_id, lyric_language, composer_name, author_name, compancy, album_new_language, album_link, years_y, months_y]
# Index: []
#
# [0 rows x 24 columns]

# %%
df4=df4.drop(['years_y','months_y'],1)
ddf4
# Out:
#             id                                 link class  singer_id  \
# 0       100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198
# 1       100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198
# 2       100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198
# 3       100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198
# 4       100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198
# ...        ...                                  ...   ...        ...
# 261484  293084  https://mojim.com/twy105001x1x1.htm  其他歌手     105001
# 261485  293085  https://mojim.com/twy105001x2x1.htm  其他歌手     105001
# 261486  293086  https://mojim.com/twy105001x3x1.htm  其他歌手     105001
# 261487  293087  https://mojim.com/twy105001x4x1.htm  其他歌手     105001
# 261488  293088  https://mojim.com/twy105001x6x1.htm  其他歌手     105001
#
#        singer_name     song_id   song_name  song_word  album_id album_name  \
# ...

# %%
df4=df4.rename(columns={'years_x':'years','months_x':'months'})

df4
# Out:
#             id                                 link class  singer_id  \
# 0       100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198
# 1       100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198
# 2       100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198
# 3       100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198
# 4       100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198
# ...        ...                                  ...   ...        ...
# 261484  293084  https://mojim.com/twy105001x1x1.htm  其他歌手     105001
# 261485  293085  https://mojim.com/twy105001x2x1.htm  其他歌手     105001
# 261486  293086  https://mojim.com/twy105001x3x1.htm  其他歌手     105001
# 261487  293087  https://mojim.com/twy105001x4x1.htm  其他歌手     105001
# 261488  293088  https://mojim.com/twy105001x6x1.htm  其他歌手     105001
#
#        singer_name     song_id   song_name  song_word  album_id album_name  \
# ...

# %%
conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8') 
pd.io.sql.to_sql(df4, "Excel18", conn,index=False, if_exists='replace')
