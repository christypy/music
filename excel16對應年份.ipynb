# %%
import xlrd
import pymysql
import math
import pandas as pd
from sqlalchemy import create_engine
from bs4 import BeautifulSoup 
import requests 
import re 
import random

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()
cur.execute("SET NAMES utf8")

sql_cmd = "SELECT * FROM music.Excel16;"
df = pd.read_sql(sql_cmd,conn)
df.head(2)
# Out:
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#        id                                 link class  singer_id singer_name  \
# 0  100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198         張洪量
# 1  100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198         張洪量
#
#       song_id song_name  song_word  album_id album_name  ... album_song  \
# 0  1001980202     情為何物           4  10019802      整個給你   ...         10
# 1  1001980204       浮萍           2  10019802      整個給你   ...         10
#
#    years months lyric_id  same_id lyric_language composer_name author_name  \
# 0   1993     01   100000   100000        Chinese           張洪量         張洪量
# 1   1993     01   100002   100002        Chinese           張洪量         張洪量
#
# ...

# %%
sql_cmd = "SELECT * FROM music.new_all_album;"
df1 = pd.read_sql(sql_cmd,conn)
df1.head(2)
# Out:
#        album_name       album_link      day years months
# 0       Only Love  /tw101108x3.htm  2000-01  2000     01
# 1   The Best Hits  /tw100711x7.htm  2000-01  2000     01

# %%
df1['album_link']=['https://mojim.com'+i for i in df1.album_link]
df1
# Out:
#                                                album_name  \
# 0                                               Only Love
# 1                                           The Best Hits
# 2                                                    感心感謝
# 3                                                    この愛に
# 4                                              歌芝居 涙の歌謡劇場
# ...                                                   ...
# 3495267                                          Together
# 3495268                           For The Rest Of My Life
# 3495269                                              Live
# 3495270            Eagles Greatest Hits Vol. 2 Remastered
# 3495271   Take It Easy / Get You In The Mood [Digital 45]
#
#                                 album_link      day years months
# 0         https://mojim.com/tw101108x3.htm  2000-01  2000     01
# 1         https://mojim.com/tw100711x7.htm  2000-01  2000     01
# 2         https://mojim.com/tw100369x1.htm  2000-01  2000     01
# ...

# %%
values=[]
for i in df.link[:]:
    data=i.split('x')
    link1=data[0].replace('/twy','/tw')
    v=link1+'x'+data[1]+'.htm'
    values.append(v)
df['album_link']=values
df.head(3)
# Out:
#        id                                 link class  singer_id singer_name  \
# 0  100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198         張洪量
# 1  100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198         張洪量
# 2  100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198         張洪量
#
#       song_id song_name  song_word  album_id album_name  ... years  months  \
# 0  1001980202     情為何物           4  10019802      整個給你   ...  1993      01
# 1  1001980204       浮萍           2  10019802      整個給你   ...  1993      01
# 2  1001980207     沙漠之花           4  10019802      整個給你   ...  1993      01
#
#   lyric_id same_id  lyric_language composer_name author_name compancy  \
# 0   100000  100000         Chinese           張洪量         張洪量       滾石
# 1   100002  100002         Chinese           張洪量         張洪量       滾石
# 2   100005  100005         Chinese           張洪量         張洪量       滾石
#
#   album_new_language                        album_link
# ...

# %%
df['album_link']=[i.strip() for i in df.album_link]
df1['album_link']=[i.strip() for i in df1.album_link]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1=df1.drop_duplicates()
df1
# Out:
#                                                album_name  \
# 0                                               Only Love
# 1                                           The Best Hits
# 2                                                    感心感謝
# 3                                                    この愛に
# 4                                              歌芝居 涙の歌謡劇場
# ...                                                   ...
# 3495267                                          Together
# 3495268                           For The Rest Of My Life
# 3495269                                              Live
# 3495270            Eagles Greatest Hits Vol. 2 Remastered
# 3495271   Take It Easy / Get You In The Mood [Digital 45]
#
#                                 album_link      day years months
# 0         https://mojim.com/tw101108x3.htm  2000-01  2000     01
# 1         https://mojim.com/tw100711x7.htm  2000-01  2000     01
# 2         https://mojim.com/tw100369x1.htm  2000-01  2000     01
# ...

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()
conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8')  

pd.io.sql.to_sql(df1, "new_all_album1", conn,index=False, if_exists='replace')

# %%
df3=pd.merge(df,df1,on='album_link',how='left')
df3
# Out:
#             id                                 link class  singer_id  \
# 0       100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198
# 1       100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198
# 2       100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198
# 3       100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198
# 4       100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198
# ...        ...                                  ...   ...        ...
# 541941  293084  https://mojim.com/twy105001x1x1.htm  其他歌手     105001
# 541942  293085  https://mojim.com/twy105001x2x1.htm  其他歌手     105001
# 541943  293086  https://mojim.com/twy105001x3x1.htm  其他歌手     105001
# 541944  293087  https://mojim.com/twy105001x4x1.htm  其他歌手     105001
# 541945  293088  https://mojim.com/twy105001x6x1.htm  其他歌手     105001
#
#        singer_name     song_id   song_name  song_word  album_id album_name_x  \
# ...

# %%
df3=df3.fillna('0')

# %%
df3.loc[(df3.day!='0')&(df3.years_x!=df3.years_y),'years_x']=df3.years_y

# %%
df3=df3.drop(['album_name_y','day','years_y','months_y'],1)
df3
# Out:
#             id                                 link class  singer_id  \
# 0       100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198
# 1       100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198
# 2       100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198
# 3       100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198
# 4       100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198
# ...        ...                                  ...   ...        ...
# 541941  293084  https://mojim.com/twy105001x1x1.htm  其他歌手     105001
# 541942  293085  https://mojim.com/twy105001x2x1.htm  其他歌手     105001
# 541943  293086  https://mojim.com/twy105001x3x1.htm  其他歌手     105001
# 541944  293087  https://mojim.com/twy105001x4x1.htm  其他歌手     105001
# 541945  293088  https://mojim.com/twy105001x6x1.htm  其他歌手     105001
#
#        singer_name     song_id   song_name  song_word  album_id album_name_x  \
# ...

# %%
df3.dr

# %%
conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8')  

pd.io.sql.to_sql(df3, "Excel17", conn,index=False, if_exists='replace')
