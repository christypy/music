# %%
import xlrd
import pymysql
import math
import pandas as pd
from sqlalchemy import create_engine
from bs4 import BeautifulSoup 
import requests 
import re 
import random

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()
cur.execute("SET NAMES utf8")

sql_cmd = "SELECT * FROM music.Excel17;"
df = pd.read_sql(sql_cmd,conn)
df.head(5)
# Out:
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#        id                                 link class  singer_id singer_name  \
# 0  100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198         張洪量
# 1  100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198         張洪量
# 2  100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198         張洪量
# 3  100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198         張洪量
# 4  100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198         張洪量
#
#       song_id song_name  song_word  album_id album_name  ... years  months  \
# 0  1001980202     情為何物           4  10019802      整個給你   ...  1993      01
# 1  1001980204       浮萍           2  10019802      整個給你   ...  1993      01
# ...

# %%
new_id=[]
list1=df.loc[df['years']==''].link.tolist()
for i in list1[:]:
    data=i.replace('https://mojim.com/twy','').replace('.htm','').split('x')
#     print(i)
    new_id.append(data[0]+'0'+data[2])
df.loc[df['years']=='','album_id']=new_id
# Out:
#             id                                 link class  singer_id  \
# 30516   225155  https://mojim.com/twy125193x1x1.htm  團體歌手     125193
# 30517   225154  https://mojim.com/twy125193x1x3.htm  團體歌手     125193
# 30518   225156  https://mojim.com/twy125193x1x2.htm  團體歌手     125193
# 45076    55715  https://mojim.com/twy130897x1x8.htm  男生歌手     130897
# 45077    55711  https://mojim.com/twy130897x1x6.htm  男生歌手     130897
# ...        ...                                  ...   ...        ...
# 261461  273494  https://mojim.com/twy170291x1x1.htm  其他歌手     170291
# 261462  274616  https://mojim.com/twy107419x1x1.htm  其他歌手     107419
# 261477  291522  https://mojim.com/twy169267x1x1.htm  其他歌手     169267
# 261478  292075  https://mojim.com/twy186221x1x2.htm  其他歌手     186221
# 261479  292076  https://mojim.com/twy186221x1x1.htm  其他歌手     186221
#
#         singer_name     song_id                         song_name  song_word  \
# ...

# %%
df.loc[df['years']==''].head(15)
# Out:
#            id                                  link class  singer_id  \
# 30516  225155   https://mojim.com/twy125193x1x1.htm  團體歌手     125193
# 30517  225154   https://mojim.com/twy125193x1x3.htm  團體歌手     125193
# 30518  225156   https://mojim.com/twy125193x1x2.htm  團體歌手     125193
# 45076   55715   https://mojim.com/twy130897x1x8.htm  男生歌手     130897
# 45077   55711   https://mojim.com/twy130897x1x6.htm  男生歌手     130897
# 45078   55721  https://mojim.com/twy130897x1x13.htm  男生歌手     130897
# 45079   55710   https://mojim.com/twy130897x1x2.htm  男生歌手     130897
# 45080   55719   https://mojim.com/twy130897x1x7.htm  男生歌手     130897
# 45081   55714  https://mojim.com/twy130897x1x12.htm  男生歌手     130897
# 45082   55712   https://mojim.com/twy130897x1x5.htm  男生歌手     130897
# 45083   55713   https://mojim.com/twy130897x1x4.htm  男生歌手     130897
# 45084   55716  https://mojim.com/twy130897x1x11.htm  男生歌手     130897
# 45085   55717   https://mojim.com/twy130897x1x9.htm  男生歌手     130897
# ...

# %%
df
# Out:
#             id                                 link class  singer_id  \
# 0       100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198
# 1       100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198
# 2       100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198
# 3       100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198
# 4       100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198
# ...        ...                                  ...   ...        ...
# 261484  293084  https://mojim.com/twy105001x1x1.htm  其他歌手     105001
# 261485  293085  https://mojim.com/twy105001x2x1.htm  其他歌手     105001
# 261486  293086  https://mojim.com/twy105001x3x1.htm  其他歌手     105001
# 261487  293087  https://mojim.com/twy105001x4x1.htm  其他歌手     105001
# 261488  293088  https://mojim.com/twy105001x6x1.htm  其他歌手     105001
#
#        singer_name     song_id   song_name  song_word  album_id album_name  \
# ...

# %%
conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8') 
pd.io.sql.to_sql(df, "Excel18", conn,index=False, if_exists='replace')
