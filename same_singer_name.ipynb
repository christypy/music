# %%
import xlrd
import pymysql
import math
import pandas as pd
from sqlalchemy import create_engine

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()
cur.execute("SET NAMES utf8")

sql_cmd = "SELECT distinct singer_id,singer_name,id,link FROM music.Excel10;"
df = pd.read_sql(sql_cmd,conn)
df.head(5)
# Out:
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#    singer_id singer_name      id                                 link
# 0     100198         張洪量  100000  https://mojim.com/twy100198x2x2.htm
# 1     100198         張洪量  100002  https://mojim.com/twy100198x2x4.htm
# 2     100198         張洪量  100005  https://mojim.com/twy100198x2x7.htm
# 3     100198         張洪量  100006  https://mojim.com/twy100198x2x8.htm
# 4     100198         張洪量  100007  https://mojim.com/twy100198x2x9.htm

# %% [markdown]
# <!-- 10的 -->

# %%
df1=df[['singer_id','singer_name']].drop_duplicates()
data_dict=df1.to_dict('records')
print(len(data_dict))
print(data_dict[0])
indices=dict()

for doc in data_dict[:]:
#     print(doc)
   
        if doc['singer_id'] not in indices:
            indices[doc['singer_id']]=[]
        indices[doc['singer_id']].append(str(doc['singer_name']))
# indices



list_key_values=[[k,v] for k ,v in indices.items()]

df_if=pd.DataFrame.from_dict(list_key_values)
df_if.columns=['singer_id','singer_name']


df_if['count']=[len(l) for l in df_if.singer_name] 
df_if=df_if.sort_values('count')
df_if
dfc=df_if[df_if['count']>1]
dfc
# Out:
# 9099
# {'singer_id': 100198, 'singer_name': '張洪量'}
#       singer_id                                        singer_name  count
# 3041     106737                                         [兄弟小文, 小文]      2
# 101      104757                                 [陳好, 陳好(Chen Hao)]      2
# 7072     172256                             [黃禮格(Hoo Leeger), 黃禮格]      2
# 999      154699                                 [The One 鄭淳元, 鄭淳元]      2
# 2132     104644                                         [人工衛星, 圈圈]      2
# ...         ...                                                ...    ...
# 2776     124806  [16 個夏天, 微時代之戀, 電視原聲帶(2014), 徵婚啟事, 我的自由年代, 巷弄裡...     49
# 1808     180933  [經典特調 II, 合輯(2017年發行), 台商最愛聽的歌, 華人碉堡音樂帝國, MY A...     52
# 3120     161281  [滾石愛情故事, Younha, Various Artists, 好先生, Zia, 美人...     57
# 998      181695  [我的電視劇情歌集, Various Artists, 최강배달꾼, 稍息立正我愛你, 愛不...     63
# 2758     161021  [眾藝人, 情歌(LOVE), Various Artists, 阿爾發全體藝人, 合輯(2...     70
#
# [282 rows x 3 columns]

# %%
sql_cmd = "SELECT distinct singer_id,singer_name,class FROM music.Excel12;"
df1 = pd.read_sql(sql_cmd,conn)
df1
# Out:
#       singer_id  singer_name class
# 0        100198          張洪量  男生歌手
# 1        100146          葉璦菱  女生歌手
# 2        100431           費翔  男生歌手
# 3        100362          楊采妮  女生歌手
# 4        122502          陳浩德  男生歌手
# ...         ...          ...   ...
# 8235     160726         Kinn  其他歌手
# 8236     169267         桃河りか  其他歌手
# 8237     186221        丸山和歌子  其他歌手
# 8238     134729  ChiliTomato  其他歌手
# 8239     105001       網友音樂創作  其他歌手
#
# [8240 rows x 3 columns]

# %%
same_id=df_if[df_if['count']>1].singer_id.values.tolist()
df3=df1[df1['singer_id'].isin(same_id)]
df3.singer_name.unique()
# Out:
# array(['合輯歌手', '張信哲( 阿哲 )', '吳浩康( Deep Ng )', '陳好( Chen Hao )',
#        '電視原聲帶(2006)', '電視原聲帶(2007)', '電視原聲帶(2013)', '關心妍',
#        '鄧紫棋( G.E.M. )', '黃鶯鶯( Tracy Huang )', '鄧麗欣( Stephy Tang )', '蕭芳芳',
#        '泳兒( Vincy Chan )', '張惠春( Saya )', '鄭希怡( Yumiko )',
#        'Transition( 前進樂團 )', '兒歌( 童謠 )', '胡雯', '蘇盈之( Soo Wincci )',
#        'io樂團( Band IO )', '張惠妹( 阿妹 )', '陳妃平', 'Ground Zero( 放射空間 )',
#        '劉若英( Rene Liu )', '伊雪莉', 'Macbeth( 馬克白 )', '1976樂團', 'SNH48',
#        'Go Go Rise( 美好前程樂團 )', '乱彈阿翔( 陳泰翔 )', '陳楚生( Chen Chusheng )',
#        '電視原聲帶(2010)', '丘丘合唱團( 丘丘樂團 )', '溫拿樂隊( The Wynners )',
#        '許雅涵( Candy )', '蓓蕾( Billie Tam )', '電影原聲帶(2012)', '電影原聲帶(2007)',
#        '電影原聲帶(2010)', '校園歌曲', '游鴻明( Chris Yu )', '張心傑',
#        '王若琳( Joanna Wang )', '小松&小柏( 小松小柏 )', '潘越雲( Michelle Pan )',
#        '貴族( 貴族精選 )', '孫建平( 孫建平&音樂廣場 )', '電視原聲帶(2011)', '芝麻與龍眼( 芝麻龍眼 )',
#        '徐靖博( BOBO )', '米拉拉', '翁倩玉( Judy Ongg )', '王珺', '馬浚偉( Steven Ma )',
# ...

# %%
df4=df3.loc[df3['class']=='團體歌手']
df4[df4['singer_name'].str.contains('合輯')]
# Out:
#       singer_id  singer_name class
# 1808     180933  合輯(2017年發行)  團體歌手
# 2758     161021  合輯(2016年發行)  團體歌手

# %%
df_if[df_if['singer_id']==106310]
# Out:
#       singer_id                           singer_name  count
# 2943     106310  [ECHO, ECHO(回聲樂團), 回聲樂團, 回聲樂團(ECHO)]      4

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()
cur.execute("SET NAMES utf8")

sql_cmd = "SELECT * FROM music.Excel12;"
df8 = pd.read_sql(sql_cmd,conn)
# Out:
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)

# %%
df8.loc[df8['singer_name']=='合輯(2017年發行)','class']='其他歌手'
# df8.loc[df8['singer_name']=='合輯(2016年發行)','class']='其他歌手'
# Out:
#             id                                   link class  singer_id  \
# 33462   273113   https://mojim.com/twy100489x39x7.htm  其他歌手     100489
# 33463   273115   https://mojim.com/twy100489x39x9.htm  其他歌手     100489
# 33464   273112   https://mojim.com/twy100489x39x6.htm  其他歌手     100489
# 33465   273117  https://mojim.com/twy100489x39x11.htm  其他歌手     100489
# 33466   273116  https://mojim.com/twy100489x39x10.htm  其他歌手     100489
# ...        ...                                    ...   ...        ...
# 236712  292313   https://mojim.com/twy110507x37x1.htm  其他歌手     110507
# 236713  292314   https://mojim.com/twy110507x37x2.htm  其他歌手     110507
# 236714  292213   https://mojim.com/twy110507x17x1.htm  其他歌手     110507
# 236715  292214   https://mojim.com/twy110507x17x2.htm  其他歌手     110507
# 236716  292315   https://mojim.com/twy110507x36x1.htm  其他歌手     110507
#
#         singer_name       song_id song_name  song_word   album_id  \
# ...

# %%
# df9=df8[['singer_id','singer_name','years']]
# df9[df9['singer_name'].str.contains('合輯')].drop_duplicates()

# %%
# df9=df8[['singer_id','singer_name','years','link']]
# df10=df9[df9['singer_id']==100411]
# df10[df10['years']=='未知']

# %%
# df8[df8['singer_name'].str.contains('合輯')].singer_name.drop_duplicates()
df8.loc[df8['singer_name'].str.contains('原聲帶'),'singer_name']='原聲帶歌手'
print(df8.loc[df8['singer_name'].str.contains('原聲帶')].singer_name.unique())
# Out:
# ['原聲帶歌手']

# %%
df8.loc[df8['singer_name'].str.contains('歌手')]
# Out:
#             id                                   link class  singer_id  \
# 3375    270676  https://mojim.com/twy104725x39x47.htm  其他歌手     104725
# 3376    270683  https://mojim.com/twy104725x39x54.htm  其他歌手     104725
# 3377    270679  https://mojim.com/twy104725x39x50.htm  其他歌手     104725
# 3378    270694  https://mojim.com/twy104725x39x65.htm  其他歌手     104725
# 3379    270643  https://mojim.com/twy104725x39x14.htm  其他歌手     104725
# ...        ...                                    ...   ...        ...
# 256090  253492   https://mojim.com/twy105458x2x12.htm  其他歌手     105458
# 256091  253475    https://mojim.com/twy105458x7x1.htm  其他歌手     105458
# 256092  253476    https://mojim.com/twy105458x6x1.htm  其他歌手     105458
# 256093  253479    https://mojim.com/twy105458x4x1.htm  其他歌手     105458
# 256094  253480    https://mojim.com/twy105458x3x1.htm  其他歌手     105458
#
#        singer_name       song_id        song_name  song_word   album_id  \
# ...

# %%
# df8[df8['singer_name'].str.contains('合輯')].singer_name.drop_duplicates()
df8.loc[df8['singer_name'].str.contains('廣告'),'singer_name']='廣告歌手'
print(df8.loc[df8['singer_name'].str.contains('廣告')].singer_name.unique())
# Out:
# ['廣告歌手']

# %%
# df8[df8['singer_name'].str.contains('合輯')].singer_name.drop_duplicates()
# df8.loc[df8['singer_name'].str.contains('廣告'),'singer_name']='廣告歌手'
print(df8.loc[df8['singer_name'].str.contains('廣告')].singer_name.unique())
# Out:
# ['廣告歌手']

# %%
conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8')  

pd.io.sql.to_sql(df8, "Excel13", conn,index=False, if_exists='replace')

# %%
# df8.loc[df8['singer_id'].isin(same_id)].singer_name
# Out:
# 5333                              合輯(2005年發行)
# 5334                              合輯(2005年發行)
# 5335                              合輯(2005年發行)
# 5336                              合輯(2005年發行)
# 5337                              合輯(2005年發行)
#                          ...
# 261357    Unfamiliar Friends Party( 不熟的朋友派對 )
# 261358    Unfamiliar Friends Party( 不熟的朋友派對 )
# 261359    Unfamiliar Friends Party( 不熟的朋友派對 )
# 261360    Unfamiliar Friends Party( 不熟的朋友派對 )
# 261361    Unfamiliar Friends Party( 不熟的朋友派對 )
# Name: singer_name, Length: 28524, dtype: object

# %%
df10=df8[['singer_id','singer_name']]
df10[df10['singer_id']==104725].drop_duplicates()
# Out:
#       singer_id singer_name
# 3375     104725          合輯

# %%
len(df10.singer_id.unique())
# Out:
# 8240

# %%
len(df10.singer_name.unique())
# Out:
# 8217

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()
cur.execute("SET NAMES utf8")

sql_cmd = "SELECT * FROM music.Excel13;"
df = pd.read_sql(sql_cmd,conn)
df.head(5)
# Out:
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#        id                                 link class  singer_id singer_name  \
# 0  100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198         張洪量
# 1  100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198         張洪量
# 2  100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198         張洪量
# 3  100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198         張洪量
# 4  100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198         張洪量
#
#       song_id song_name  song_word  album_id album_name album_language  \
# 0  1001980202      情為何物          4  10019802       整個給你             國語
# 1  1001980204        浮萍          2  10019802       整個給你             國語
# ...

# %%
df1=df[['album_id','album_name','years','singer_id','singer_name']].drop_duplicates()
df1
# Out:
#          album_id               album_name years  singer_id singer_name
# 0        10019802                     整個給你  1993     100198         張洪量
# 10      100198010                       祭文  1987     100198         張洪量
# 19      100198012  全世界只有你不知道[新歌+精選跨時空情歌全集]  2004     100198         張洪量
# 39       10019806                    情定日落橋  1997     100198         張洪量
# 56      100198011                 滾石香港黃金十年  2003     100198         張洪量
# ...           ...                      ...   ...        ...         ...
# 261484   10500101                     痛徹心扉    未知     105001      網友音樂創作
# 261485   10500102                       朝代    未知     105001      網友音樂創作
# 261486   10500103                    愛情的樂章    未知     105001      網友音樂創作
# 261487   10500104                   你離開的事實    未知     105001      網友音樂創作
# 261488   10500106                  分開的最後一天    未知     105001      網友音樂創作
#
# [36052 rows x 5 columns]

# %%
df1[df1['singer_id']==104725].sort_values('years')
# Out:
#        album_id                    album_name years  singer_id singer_name
# 4311  104725046    卡通歌王 Fun Fun Cartoon Songs  1905     104725        合輯歌手
# 4204  104725043                 音樂無極限華納十週年演唱會  1905     104725        合輯歌手
# 3532  104725044                         1碟主題曲  1905     104725        合輯歌手
# 4272   10472508                      Top主題曲精選  1905     104725        合輯歌手
# 4186   10472507                 新戀愛世代[之愛的初告白]  2003     104725        合輯歌手
# 4206  104725012         散場電影院[Memory Theater]  2003     104725        合輯歌手
# 4224  104725027                       我的祕密情歌1  2003     104725        合輯歌手
# 4240  104725032                           簡單愛  2003     104725        合輯歌手
# 4257   10472505                       Top廣告精選  2003     104725        合輯歌手
# 4281  104725030                  純感覺Pure Love  2003     104725        合輯歌手
# 4295  104725028                       我的祕密情歌2  2003     104725        合輯歌手
# ...
