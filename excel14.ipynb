# %%
import xlrd
import pymysql
import math
import pandas as pd
from sqlalchemy import create_engine
from bs4 import BeautifulSoup 
import requests 
import re 
import random

# %%
conn = pymysql.connect(
        host='localhost', 
        user='root', 
        passwd = 'fc117108',
        db='music',
        port=3306,
        charset='utf8'
        )
cur = conn.cursor()
cur.execute("SET NAMES utf8")

sql_cmd = "SELECT * FROM music.new;"
new = pd.read_sql(sql_cmd,conn)
new.head(2)
# Out:
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#    no singer_link singer            album    song  \
# 0   1      100198    張洪量           珠穆朗瑪峰   珠穆朗瑪峰
# 1   2      100198    張洪量  張洪量 作品13 格陵蘭情書   格陵蘭情書
#
#                                    link     year langrage compancy
# 0  https://mojim.com/twy100198x15x1.htm  2019-07       國語      未記錄
# 1  https://mojim.com/twy100198x14x1.htm  2016-04       國語       滾石

# %%
new['link']=new['link'].str.replace('//twy','/twy')

# %%
new.loc[new['year'].str.contains('三洋唱片出版社' ),'compancy']=new.year
new.loc[new['year'].str.contains('三洋唱片出版社' ),'year']='未記錄'
new.loc[new['compancy'].str.contains('三洋唱片出版社' )]
# Out:
#             no singer_link             singer      album           song  \
# 132761  132762      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9         到底愛我不愛
# 132762  132763      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9        再會吧！心上人
# 132763  132764      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9           流水寄情
# 132764  132765      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9          呢喃的燕子
# 132765  132766      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9        陽光海浪和白雲
# 132766  132767      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9             我願
# 132767  132768      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9           長崎之女
# 132768  132769      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9           初夏戀歌
# 132769  132770      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9        夜來花香送情郎
# 132770  132771      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9           雲水故鄉
# 132771  132772      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9   最後一杯酒(我倆再相逢)
# 132772  132773      100114  陳淑樺( Sarah Chen )  明星珍藏集錦 9   美麗藉口詞(漫步山林間)
# ...

# %%
new.loc[new['year'].str.contains('光美_Kaa613' ),'compancy']=new.year
new.loc[new['year'].str.contains('光美_Kaa613' ),'year']='未記錄'
new.loc[new['compancy'].str.contains('光美_Kaa613' )]
# Out:
#             no singer_link     singer           album      song  \
# 119214  119215      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]       收音機
# 119215  119216      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]        舞會
# 119216  119217      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]      墨綠的夜
# 119217  119218      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]     我們的理想
# 119218  119219      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]       為什麼
# 119219  119220      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]      留一盞燈
# 119220  119221      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]    早餐的瑪麗亞
# 119221  119222      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]   令人傷心的笑話
# 119222  119223      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]     空白明信片
# 119223  119224      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]      愛的迷宮
# 119224  119225      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]     夏天的日記
# 119225  119226      102206  邰肇玫( 小玫 )  留一盞燈[邰肇玫同名專輯]      也許你曾
#
#                                         link year langrage   compancy
# 119214   https://mojim.com/twy102206x6x1.htm  未記錄       國語  光美_Kaa613
# ...

# %%
# new.loc[new['year'].str.contains('2000/9/30' ),'compancy']=new.year
new.loc[new['year'].str.contains('2000/9/30' ),'year']='2000-09'
# new.loc[new['compancy'].str.contains('光美_Kaa613' )]
new.loc[new['year'].str.contains('2000/9/30' )]
# Out:
# Empty DataFrame
# Columns: [no, singer_link, singer, album, song, link, year, langrage, compancy]
# Index: []

# %%
# new.loc[new['year'].str.contains('2000/9/30' ),'compancy']=new.year
new.loc[new['year']=='2001.12','year']='2001-12'
# new.loc[new['compancy'].str.contains('光美_Kaa613' )]
new.loc[new['year']=='2001-12' ]
# Out:
#             no singer_link               singer album      song  \
# 615        616      100431  費翔( Kris Phillips )   野花      以防萬一
# 616        617      100431  費翔( Kris Phillips )   野花       橄欖樹
# 617        618      100431  費翔( Kris Phillips )   野花        野花
# 618        619      100431  費翔( Kris Phillips )   野花   Love Me
# 619        620      100431  費翔( Kris Phillips )   野花        難題
# ...        ...         ...                  ...   ...       ...
# 278974  278975      102117                淑惠&美娜  兩個人       生氣你
# 278975  278976      102117                淑惠&美娜  兩個人        塗鴨
# 278976  278977      102117                淑惠&美娜  兩個人      寫一封信
# 278977  278978      102117                淑惠&美娜  兩個人        你呀
# 278978  278979      102117                淑惠&美娜  兩個人        閉嘴
#
#                                         link     year langrage compancy
# 615      https://mojim.com/twy100431x5x1.htm  2001-12       國語       豐華
# ...

# %%
# new.loc[new['year'].str.contains('2000/9/30' ),'compancy']=new.year
new.loc[new['year']=='2008.12','year']='2008-12'
# new.loc[new['compancy'].str.contains('光美_Kaa613' )]
new.loc[new['year']=='2008-12' ]
# Out:
#             no singer_link         singer       album               song  \
# 2352      2353      100285     詹雅雯( 詹雅文 )        戀情海           原來你不識愛過我
# 2353      2354      100285     詹雅雯( 詹雅文 )        戀情海              單身的演歌
# 2354      2355      100285     詹雅雯( 詹雅文 )        戀情海                戀情海
# 2355      2356      100285     詹雅雯( 詹雅文 )        戀情海              漂浪的海沙
# 2356      2357      100285     詹雅雯( 詹雅文 )        戀情海                霧煞煞
# ...        ...         ...            ...         ...                ...
# 303155  303156      105652            溫晉禾  想念聖誕 (EP)   想念(Anthonywen 版)
# 303156  303157      105652            溫晉禾  想念聖誕 (EP)     想念(Saxphone 版)
# 303157  303158      105652            溫晉禾  想念聖誕 (EP)           想念(Kala)
# 303361  303362      105888            彭麗麗  親愛的我一直在想你          親愛的我一直在想你
# 304346  304347      105760  bro-5( BRO5 )       亂世起舞               亂世起舞
#
#                                         link     year langrage compancy
# ...

# %%
new.loc[new['year']=='89268' ,'compancy']=new.year
new.loc[new['year']=='89268','year']='未記錄'
# new.loc[new['compancy'].str.contains('光美_Kaa613' )]
new.loc[new['year']=='89268' ]
# Out:
# Empty DataFrame
# Columns: [no, singer_link, singer, album, song, link, year, langrage, compancy]
# Index: []

# %%
new.year.unique()
# Out:
# array(['2019-07', '2016-04', '2004-04', '2003-03', '2000-11', '1997-11',
#        '1996-09', '1995-07', '1994-11', '1993-01', '1992-04', '1990-12',
#        '1989-07', '1987-09', '未記錄', '2013-01', '2001-05', '2000-12',
#        '2000-07', '1999', '1996', '1994', '1993-12', '1993-04', '1992',
#        '1990', '1986', '1985', '2014-12', '2007-12', '2004-12', '2004-02',
#        '2001-12', '2001-01', '2000-10', '2000-05', '2000-03', '1997-12',
#        '1997-04', '1997', '1996-12', '1996-01', '1995-12', '1995-05',
#        '1994-04', '2002-01', '1999-07', '1990-06', '1985-01', '2005-02',
#        '2003-04', '2002-12', '2002-11', '1984-09', '1983', '1982',
#        '1981-01', '1981', '1978-01', '1977-08', '1977', '1976', '1975',
#        '2017-06', '2017-05', '2016-12', '2014-01', '2013-09', '2013-04',
#        '2012-04', '2011-04', '2010-05', '2010-04', '2009-04', '2008-04',
#        '2007-04', '2006-04', '2005-01', '2003-09', '2003-01', '2002-07',
# ...

# %%
print(len(new.year))
year=[i.split('-')[0] if  '-' in i  else i for i in new.year ]
month=[i.split('-')[1] if  '-' in i  else('只有年份' if len(i)>2  else i) for i in new.year ]

new['years']=year
new['month']=month
new.sample(20)
# Out:
# 305158
#             no singer_link                 singer                  album  \
# 57414    57415      101072          黃思婷( Sheryl )                    祈禱
# 175348  175349      104500            張杰( Jason )                     拾
# 301372  301373      172649                    王韻齊                 不做花心男
# 47388    47389      100061     林慧萍( Monique Lin )                  往昔金曲
# 265754  265755      100457                    羅映庭               把心事想個清楚
# 48538    48539      105703          鄧紫棋( G.E.M. )  借物少女艾莉緹動畫電影 - 亞莉亞蒂之歌
# 116443  116444      109683        崔萍( Tsui Ping )       崔萍．臉兒甜如糖 (經典年代)
# 9731      9732      104724            合輯(2002年發行)              最愛熱門電影金曲
# 251221  251222      100466              林利( 林立洋 )                  當我懂得
# 24428    24429      101019        羅文( Roman Tam )           沈殿霞‧羅文 No.1
# 295540  295541      111110              L.C( Lc )            羽絨外套( XXL)
# 186814  186815      106396          李爍( Li Shuo )                   相見歡
# ...

# %%
conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8')  

pd.io.sql.to_sql(new, "new1", conn,index=False, if_exists='replace')

# %%
sql_cmd = "SELECT * FROM music.new1;"
new1 = pd.read_sql(sql_cmd,conn)
new1.head(2)
# Out:
#    no singer_link singer            album    song  \
# 0   1      100198    張洪量           珠穆朗瑪峰   珠穆朗瑪峰
# 1   2      100198    張洪量  張洪量 作品13 格陵蘭情書   格陵蘭情書
#
#                                    link     year langrage compancy years month
# 0  https://mojim.com/twy100198x15x1.htm  2019-07       國語      未記錄  2019    07
# 1  https://mojim.com/twy100198x14x1.htm  2016-04       國語       滾石  2016    04

# %%
new1.drop(['no','year'],axis=1,inplace=True)
new1
# Out:
#        singer_link  singer                     album           song  \
# 0           100198     張洪量                    珠穆朗瑪峰          珠穆朗瑪峰
# 1           100198     張洪量           張洪量 作品13 格陵蘭情書          格陵蘭情書
# 2           100198     張洪量           張洪量 作品13 格陵蘭情書   格陵蘭情書〔口白＋音樂〕
# 3           100198     張洪量           張洪量 作品13 格陵蘭情書      格陵蘭情書〔音樂〕
# 4           100198     張洪量  全世界只有你不知道[新歌+精選跨時空情歌全集]      全世界只有你不知道
# ...            ...     ...                       ...            ...
# 305153      105001  網友音樂創作                     痛徹心扉      痛徹心扉(孫培恩)
# 305154      105001  網友音樂創作                       朝代             朝代
# 305155      105001  網友音樂創作                    愛情的樂章          愛情的樂章
# 305156      105001  網友音樂創作                   你離開的事實         你離開的事實
# 305157      105001  網友音樂創作                        暫存       分開的最後一天
#
#                                         link langrage compancy years month
# 0       https://mojim.com/twy100198x15x1.htm       國語      未記錄  2019    07
# ...

# %%
sql_cmd = "SELECT * FROM music.Excel13;"
df = pd.read_sql(sql_cmd,conn)
df.head(2)
# Out:
#        id                                 link class  singer_id singer_name  \
# 0  100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198         張洪量
# 1  100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198         張洪量
#
#       song_id song_name  song_word  album_id album_name album_language  \
# 0  1001980202      情為何物          4  10019802       整個給你             國語
# 1  1001980204        浮萍          2  10019802       整個給你             國語
#
#    album_song years month  lyric_id same_id lyric_language composer_name  \
# 0          10  1993     1    100000  100000        Chinese           張洪量
# 1          10  1993     1    100002  100002        Chinese           張洪量
#
#   author_name
# 0         張洪量
# 1         張洪量

# %%
df3=pd.merge(df,new1,on='link',how='left')

print(len(df3))
df3.head(5)
# Out:
# 261489
#        id                                 link class  singer_id singer_name  \
# 0  100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198         張洪量
# 1  100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198         張洪量
# 2  100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198         張洪量
# 3  100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198         張洪量
# 4  100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198         張洪量
#
#       song_id song_name  song_word  album_id album_name  ... composer_name  \
# 0  1001980202      情為何物          4  10019802       整個給你  ...           張洪量
# 1  1001980204        浮萍          2  10019802       整個給你  ...           張洪量
# 2  1001980207      沙漠之花          4  10019802       整個給你  ...           張洪量
# 3  1001980208     我想我瘋了          5  10019802       整個給你  ...           張洪量
# 4  1001980209       外星戀          3  10019802       整個給你  ...           張洪量
#
# ...

# %%
df3.columns
# Out:
# Index(['id', 'link', 'class', 'singer_id', 'singer_name', 'song_id',
#        'song_name', 'song_word', 'album_id', 'album_name', 'album_language',
#        'album_song', 'years_x', 'month_x', 'lyric_id', 'same_id',
#        'lyric_language', 'composer_name', 'author_name', 'singer_link',
#        'singer', 'album', 'song', 'langrage', 'compancy', 'years_y',
#        'month_y'],
#       dtype='object')

# %%
df3['singer_name']=df3['singer']
df3['album_name']=df3['album']
df3['song_name']=df3['song']
df3['album_language']=df3['langrage']
df3['years_x']=df3['years_y']
df3['month_x']=df3['month_y']
df4=df3.drop(['singer_link','singer','album','song','langrage','years_y','month_y'],1)
df4
# Out:
#             id                                 link class  singer_id  \
# 0       100000  https://mojim.com/twy100198x2x2.htm  男生歌手     100198
# 1       100002  https://mojim.com/twy100198x2x4.htm  男生歌手     100198
# 2       100005  https://mojim.com/twy100198x2x7.htm  男生歌手     100198
# 3       100006  https://mojim.com/twy100198x2x8.htm  男生歌手     100198
# 4       100007  https://mojim.com/twy100198x2x9.htm  男生歌手     100198
# ...        ...                                  ...   ...        ...
# 261484  293084  https://mojim.com/twy105001x1x1.htm  其他歌手     105001
# 261485  293085  https://mojim.com/twy105001x2x1.htm  其他歌手     105001
# 261486  293086  https://mojim.com/twy105001x3x1.htm  其他歌手     105001
# 261487  293087  https://mojim.com/twy105001x4x1.htm  其他歌手     105001
# 261488  293088  https://mojim.com/twy105001x6x1.htm  其他歌手     105001
#
#        singer_name     song_id   song_name  song_word  album_id album_name  \
# ...

# %%
conn = create_engine('mysql+pymysql://root:fc117108@localhost:3306/music',encoding='utf8')  

pd.io.sql.to_sql(df4, "Excel14", conn,index=False, if_exists='replace')
